# %%
% matplotlib notebook
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn import linear_model
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score

# %%
url_set = "./grillos.csv"
df = pd.read_csv(url_set,header = 0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 2 columns):
# X    15 non-null float64
# Y    15 non-null float64
# dtypes: float64(2)
# memory usage: 320.0 bytes

# %%
df.head()
# Out:
#            X          Y
# 0  20.000000  88.599998
# 1  16.000000  71.599998
# 2  19.799999  93.300003
# 3  18.400000  84.300003
# 4  17.100000  80.599998

# %%
X = df.iloc[:,:1].values

# %%
Y = df.iloc[:,1:].values

# %%
fig = plt.figure()
plt.grid(False)
fig = plt.scatter(X, Y, color='green')
plt.suptitle("Chirridos vs Temperatura")

plt.xlabel('Temperatura') 
plt.ylabel('Chirridos')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from sklearn.model_selection import train_test_split

# %%
# create training and testing vars
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3)
print( X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (10, 1) (10, 1)
# (5, 1) (5, 1)

# %%
# Create linear regression object
regr = linear_model.LinearRegression()

# %%
model = regr.fit(X_train, y_train)
y_pred = regr.predict(X_test)

# %%
# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(y_test, y_pred))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(y_test, y_pred))
# Out:
# Coefficients:
#  [[3.4357584]]
# Mean squared error: 14.72
# Variance score: 0.37

# %%
accuracy = r2_score(y_test, y_pred)
print("Precisión de predicción cruzada:", accuracy)
# Out:
# Precisión de predicción cruzada: 0.37024333051044067

# %%
# Plot outputs
fig = plt.figure()
X_test = X_test
plt.scatter(X_test, y_test,  color='green')
plt.scatter(X_train, y_train,  color='red')
plt.plot(X_test, y_pred, color='blue', linewidth=5)
plt.grid()

plt.xticks(())
plt.yticks(())
plt.suptitle("Chirridos vs Temperatura")
plt.xlabel('Temperatura') 
plt.ylabel('Chirridos')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
